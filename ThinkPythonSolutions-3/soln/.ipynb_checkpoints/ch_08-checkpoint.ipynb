# %%
fruit = 'banana'
letter = fruit[1]
letter

# lunghezza di una stringa
n = len(fruit)
print("\nLunghezza della stringa len(fruit)")
print(n)

# ultima lettere di una stringa
print("\nUltima lettera della stringa fruit[n-1]")
print(fruit[n-1])
print("\n...oppure con fruit[-1]")
print(fruit[-1])
# Out:
# Lunghezza della stringa len(fruit)
# 6
#
# Ultima lettera della stringa fruit[n-1]
# a
#
# ...oppure con fruit[-1]
# a

# %%
# string slices
fruit = 'banana'

slice = fruit[0:3]
slice
# Out:
# 'ban'
